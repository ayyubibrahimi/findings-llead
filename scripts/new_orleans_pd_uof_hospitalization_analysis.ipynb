# %%
import pandas as pd
import statsmodels.api as sm
import pymc as pm
import arviz as az
import numpy as np
from scipy.stats import chi2_contingency
# Out:
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
df = pd.read_csv("../data/findings/new_orleans_pd_uof_2016_2022.csv")

df.head(10)
# Out:
#                         tracking_id                 originating_bureau  \
# 0  1fb5b1fcbf30fa9feb0a4fd2e2ae7b00            field operations bureau
# 1  888fc1d84fd0bb20c52627a603025e24            field operations bureau
# 2  888fc1d84fd0bb20c52627a603025e24            field operations bureau
# 3  fc500256497f7b93fb89605cacec4eb8            field operations bureau
# 4  731920c88a49cc3ec37ed7f995f28586  investigations and support bureau
# 5  215d5ce2caf07ce5f8b2aa2abe372507            field operations bureau
# 6  215d5ce2caf07ce5f8b2aa2abe372507            field operations bureau
# 7  2853e3521ca8e59ab045f8f15b322880            field operations bureau
# 8  2853e3521ca8e59ab045f8f15b322880            field operations bureau
# 9  e3974551818eb8df3fa57e08974890bc            field operations bureau
#
#             division_level     division       unit   working_status  \
# 0                 recruits    a platoon     patrol      paid detail
# 1             2nd district    c platoon        NaN              NaN
# 2             2nd district    c platoon        NaN              NaN
# 3             1st district  3rd platoon        NaN              NaN
# 4  criminal investigations     homicide    squad e              NaN
# 5             8th district    c platoon     patrol              NaN
# 6             8th district    c platoon     patrol              NaN
# 7             5th district    narcotics  narcotics  regular working
# 8             5th district    narcotics  narcotics  regular working
# 9             2nd district    b platoon     patrol              NaN
#
#         shift_time investigation_status              disposition  \
# 0  between 7am-3pm            Completed   use of force justified
# 1              NaN            Completed  use of force authorized
# 2              NaN            Completed  use of force authorized
# 3              NaN            Completed  use of force authorized
# 4              NaN            Completed  use of force authorized
# 5              NaN            Completed  use of force authorized
# 6              NaN            Completed  use of force authorized
# 7              NaN            Completed  use of force authorized
# 8              NaN            Completed  use of force authorized
# 9              NaN            Completed  use of force authorized
#
#        service_type  ... citizen_injured citizen_influencing_factors  \
# 0  call for service  ...              no                         NaN
# 1         arresting  ...             yes  alchohol and unknown drugs
# 2         arresting  ...             yes  alchohol and unknown drugs
# 3  call for service  ...              no  alchohol and unknown drugs
# 4  call for service  ...              no                     unknown
# 5         arresting  ...              no                     unknown
# 6         arresting  ...              no                     unknown
# 7             other  ...              no                    alchohol
# 8             other  ...              no                    alchohol
# 9  call for service  ...              no                     unknown
#
#   citizen_distance_from_officer  citizen_age  citizen_build   citizen_height  \
# 0                           NaN          NaN            NaN              NaN
# 1              0 feet to 1 feet         29.0          large          > 6'3''
# 2              0 feet to 1 feet         29.0          large          > 6'3''
# 3             7 feet to 10 feet         29.0         medium  5'10'' to 6'0''
# 4              0 feet to 1 feet         19.0         medium   5'7'' to 5'9''
# 5              0 feet to 1 feet         22.0          small   5'4'' to 5'6''
# 6              0 feet to 1 feet         22.0          small   5'4'' to 5'6''
# 7             7 feet to 10 feet         27.0         medium  5'10'' to 6'0''
# 8             7 feet to 10 feet         27.0         medium  5'10'' to 6'0''
# 9              4 feet to 6 feet         15.0          small   5'0'' to 5'3''
#
#   citizen_arrested        citizen_arrest_charges        agency_y  \
# 0              NaN                           NaN  new-orleans-pd
# 1              yes                           NaN  new-orleans-pd
# 2              yes                           NaN  new-orleans-pd
# 3               no                           NaN  new-orleans-pd
# 4              yes                           NaN  new-orleans-pd
# 5              yes  illegal carrying of a weapon  new-orleans-pd
# 6              yes  illegal carrying of a weapon  new-orleans-pd
# 7              yes                           NaN  new-orleans-pd
# 8              yes                           NaN  new-orleans-pd
# 9               no                           NaN  new-orleans-pd
#
#                         citizen_uid
# 0  ccaa67bd6140cd3e7774c99295c8b5d9
# 1  354b7df12d7748042d9127690dfc73df
# 2  354b7df12d7748042d9127690dfc73df
# 3  934d6ce00d0375d9f08caebe6c2e67d9
# 4  ac04a4772e6a64b901112801421cd1c1
# 5  7f8031a29da0cd375373d6b2c1e0d6b1
# 6  7f8031a29da0cd375373d6b2c1e0d6b1
# 7  96c1c0621f0e7a2b111309b65a3363ef
# 8  96c1c0621f0e7a2b111309b65a3363ef
# 9  c49495a72d50cdd677853a229e4b5efe
#
# [10 rows x 51 columns]

# %%
# preprocess data 

df = df.dropna(subset=['citizen_race', 'citizen_hospitalized'])

df['citizen_hospitalized'] = df['citizen_hospitalized'].apply(lambda x: 1 if x == 'yes' else 0)

df = pd.get_dummies(df, columns=['citizen_race'])

races = ['asian / pacific islander', 'black', 'hispanic', 'indian', 'white']

# %%
logit_results = {}

for race in races:
    y = df['citizen_hospitalized']
    X = sm.add_constant(df[f'citizen_race_{race}']) 
    model = sm.Logit(y, X)
    result = model.fit(disp=0) 
    logit_results[race] = result.summary()

logit_results

# Asian / Pacific Islander: The coefficient is approximately 0.167. This suggests that, all else being equal, 
# being Asian / Pacific Islander is associated with an increase in the log-odds of hospitalization.

# Black: The coefficient is approximately -0.401. This suggests that, all else being equal, 
# being Black is associated with a decrease in the log-odds of hospitalization.

# Hispanic: The coefficient is approximately -0.429. This suggests that, all else being equal, 
# being Hispanic is associated with a decrease in the log-odds of hospitalization.

# Indian: The coefficient is approximately 1.618. This suggests that, all else being equal, 
# being Indian is associated with an increase in the log-odds of hospitalization.

# White: The coefficient is approximately 0.501. This suggests that, all else being equal, 
# being White is associated with an increase in the log-odds of hospitalization.
# Out:
# {'asian / pacific islander': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7790
#  Model:                            Logit   Df Residuals:                     7788
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:               2.348e-05
#  Time:                          11:19:26   Log-Likelihood:                -5254.2
#  converged:                         True   LL-Null:                       -5254.3
#  Covariance Type:              nonrobust   LLR p-value:                    0.6194
#  =========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------------------------
#  const                                    -0.3908      0.023    -16.881      0.000      -0.436      -0.345
#  citizen_race_asian / pacific islander     0.1676      0.336      0.499      0.618      -0.491       0.827
#  =========================================================================================================
#  """,
#  'black': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7790
#  Model:                            Logit   Df Residuals:                     7788
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:                0.003743
#  Time:                          11:19:26   Log-Likelihood:                -5234.6
#  converged:                         True   LL-Null:                       -5254.3
#  Covariance Type:              nonrobust   LLR p-value:                 3.572e-10
#  ======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                 -0.0499      0.059     -0.850      0.395      -0.165       0.065
#  citizen_race_black    -0.4016      0.064     -6.290      0.000      -0.527      -0.276
#  ======================================================================================
#  """,
#  'hispanic': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7790
#  Model:                            Logit   Df Residuals:                     7788
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:               0.0005995
#  Time:                          11:19:26   Log-Likelihood:                -5251.1
#  converged:                         True   LL-Null:                       -5254.3
#  Covariance Type:              nonrobust   LLR p-value:                   0.01207
#  =========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
#  -----------------------------------------------------------------------------------------
#  const                    -0.3818      0.023    -16.381      0.000      -0.428      -0.336
#  citizen_race_hispanic    -0.4291      0.175     -2.452      0.014      -0.772      -0.086
#  =========================================================================================
#  """,
#  'indian': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7790
#  Model:                            Logit   Df Residuals:                     7788
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:                0.001186
#  Time:                          11:19:26   Log-Likelihood:                -5248.1
#  converged:                         True   LL-Null:                       -5254.3
#  Covariance Type:              nonrobust   LLR p-value:                 0.0004152
#  =======================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------
#  const                  -0.3943      0.023    -17.045      0.000      -0.440      -0.349
#  citizen_race_indian     1.6181      0.509      3.177      0.001       0.620       2.616
#  =======================================================================================
#  """,
#  'white': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7790
#  Model:                            Logit   Df Residuals:                     7788
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:                0.004933
#  Time:                          11:19:27   Log-Likelihood:                -5228.4
#  converged:                         True   LL-Null:                       -5254.3
#  Covariance Type:              nonrobust   LLR p-value:                 6.038e-13
#  ======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                 -0.4528      0.025    -18.257      0.000      -0.501      -0.404
#  citizen_race_white     0.5013      0.070      7.211      0.000       0.365       0.638
#  ======================================================================================
#  """}

# %%
chi2_results = {}

for race in races:
    contingency_table = pd.crosstab(df['citizen_hospitalized'], df[f'citizen_race_{race}'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[race] = {'Chi-square Statistic': chi2, 'p-value': p}

chi2_results

# Asian / Pacific Islander: The p-value is approximately 0.74, which is greater than 0.05. Therefore, we do not 
# reject the null hypothesis that hospitalization is independent of being Asian / Pacific Islander.

# Black: The p-value is extremely small (much less than 0.05). Therefore, we reject the null hypothesis 
# and conclude that there is a significant association between hospitalization and being Black.

# Hispanic: The p-value is approximately 0.016, which is less than 0.05. Therefore, we reject the null hypothesis 
# and conclude that there is a significant association between hospitalization and being Hispanic.

# Indian: The p-value is small (less than 0.05). Therefore, we reject the null hypothesis and conclude that 
# there is a significant association between hospitalization and being Indian.

# White: The p-value is extremely small (much less than 0.05). Therefore, we reject the null hypothesis 
# and conclude that there is a significant association between hospitalization and being White.
# Out:
# {'asian / pacific islander': {'Chi-square Statistic': 0.10817223442255777,
#   'p-value': 0.7422346935631141},
#  'black': {'Chi-square Statistic': 39.481020090751386,
#   'p-value': 3.3126350731360034e-10},
#  'hispanic': {'Chi-square Statistic': 5.697850306740474,
#   'p-value': 0.01698570437785355},
#  'indian': {'Chi-square Statistic': 10.989234987653955,
#   'p-value': 0.0009164263076338237},
#  'white': {'Chi-square Statistic': 52.232560903096605,
#   'p-value': 4.930183145635031e-13}}

# %%
# preprocess data
df = df.dropna(subset=['citizen_sex'])

df = pd.get_dummies(df, columns=['citizen_sex'])
genders = ['female', 'male']

# %%
logit_results_gender = {}

for gender in genders:
    y = df['citizen_hospitalized']
    X = sm.add_constant(df[f'citizen_sex_{gender}']) 
    model = sm.Logit(y, X)
    result = model.fit(disp=0) 
    logit_results_gender[gender] = result.summary()

logit_results_gender

# For female', the coefficient is 0.3671. This means that, all else being equal, being female is associated with an 
# increase in the log-odds of hospitalization by about 0.37 units. 
# Conversely, for 'male', the coefficient is -0.3671, meaning being male is associated with a decrease in the 
# log-odds of hospitalization by about 0.37 units.
# Out:
# {'female': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7779
#  Model:                            Logit   Df Residuals:                     7777
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:                0.002824
#  Time:                          11:19:27   Log-Likelihood:                -5231.1
#  converged:                         True   LL-Null:                       -5245.9
#  Covariance Type:              nonrobust   LLR p-value:                 5.235e-08
#  ======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                 -0.4410      0.025    -17.686      0.000      -0.490      -0.392
#  citizen_sex_female     0.3671      0.067      5.461      0.000       0.235       0.499
#  ======================================================================================
#  """,
#  'male': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              Logit Regression Results
#  ================================================================================
#  Dep. Variable:     citizen_hospitalized   No. Observations:                 7779
#  Model:                            Logit   Df Residuals:                     7777
#  Method:                             MLE   Df Model:                            1
#  Date:                  Thu, 13 Jul 2023   Pseudo R-squ.:                0.002824
#  Time:                          11:19:27   Log-Likelihood:                -5231.1
#  converged:                         True   LL-Null:                       -5245.9
#  Covariance Type:              nonrobust   LLR p-value:                 5.235e-08
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const               -0.0740      0.062     -1.185      0.236      -0.196       0.048
#  citizen_sex_male    -0.3671      0.067     -5.461      0.000      -0.499      -0.235
#  ====================================================================================
#  """}

# %%
odds_ratios = {}

for gender in genders:
    y = df['citizen_hospitalized']
    X = sm.add_constant(df[f'citizen_sex_{gender}'])  # adding a constant
    model = sm.Logit(y, X)
    result = model.fit(disp=0)  # disp=0 suppresses convergence messages
    logit_results_gender[gender] = {"result": result, "summary": result.summary()}

for gender, outputs in logit_results_gender.items():
    odds_ratios[gender] = np.exp(outputs["result"].params)

odds_ratios

# The odds of hospitalization for females are 1.44 times the odds of hospitalization for non-females, 
# holding all else constant. This is about a 44% increase in the odds of hospitalization.

# The odds of hospitalization for males are 0.69 times the odds of hospitalization for non-males, 
# holding all else constant. This is about a 31% decrease in the odds of hospitalization.
# Out:
# {'female': const                 0.643379
#  citizen_sex_female    1.443482
#  dtype: float64,
#  'male': const               0.928705
#  citizen_sex_male    0.692769
#  dtype: float64}
